# %% [markdown]
# # Intro cómputo Cuántico
#
# ## Mecánica Cuántica 1900
# - Ec. Schrodinger
# - Función de onda
# - Se pierde el concepto de trayectoria
# - De Broglie -> Dualidda Onda-Particula
# - Radiacion del cuerpo negro
#   - Stephan-Boltzman
#   - Wien
#   - Rayleigh y Jeans
#   - Planck  -> $E = nh\nu$ $R = \frac{2\pi\nu^2}{c^2} \frac{h\nu}{e^{}-1}$
# - Efecto fotoelectrico
# - Espectro de emisión del átomo

# %% [markdown]
# ## Función de onda
# $$\psi(x,t) = \int^{-\infty}_{\infty}f(x)e^{i(\pi x - wt)}dt$$
#
# ## Densidad de probabilidad

# %% [markdown]
# ## Postulados de la M.C.
#
# 1.$|\psi> =\in H$ -> $H = H(F)$ con $F = R$ o $F = C$
#
# 2. Cualquier cantidad fisica medible se asocia a un operador $\hat{A}$
#    $\hat{A}$: H -> H. $\hat{A}$ Observable -> $\hat{A} = \hat{A^t}$
#
# 3. Lo que medimos en $\hat{A}$ solo pueden ser sus eigenvalores
#
# 4. Probabilidad
# 	$P(a_n) = |<a_n|\psi(t)>|^2 = |C_n(t)|^2$
#
# 5. $|u>$ -> $|a_n>$ luego de medir el op $\hat{A}$
#
# 6. Ec. de estado $E|u> = H|\psi>$

# %% [markdown]
# ## Descomposición espectral
#
# dado ${|\psi>}$ de eigenestado de $\hat{A}$
# $\hat{A}|a_n> = a_n|a_n>$

# %% [markdown]
# ## Antes (normales)
# bits:
#
# 0-1, encendido - apagado
#
# ## Cuántico:
# Qbits:
#
# Estado en superposición hasta ser medido. Una probabilidad. LO podemos definir como:
#
# $|q> = a|0> + b|1>$ a y b definen la probabilidda de ser 0 o 1
#
# ### Tipos de qbits
#
# - Superconductores:
# - Trampas opticas
# - Trampas ionicas

# %% [markdown]
# # Programación de compuertas

# %%
# %pip install qiskit==1.4.0
# %pip install matplotlib
# %pip install pylatexenc

# %%
from qiskit import *

#Circuito cuanticos

qc = QuantumCircuit(1,1)

qc.x(0)
qc.draw('mpl')

# %%
qc = QuantumCircuit(1,1)

qc.y(0)
qc.draw('mpl')

# %%
qc = QuantumCircuit(1)

qc.y(0)
qc.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 qc = QuantumCircuit(1)
# ----> 3 qc.H(0)
#       4 qc.draw('mpl')
#
# AttributeError: 'QuantumCircuit' object has no attribute 'H'
